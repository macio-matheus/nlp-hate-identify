# %%
import pandas as pd
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn import preprocessing as pre
#from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.externals import joblib

# %%
# Preprocessing dataset comments hate wikipedia
df = pd.read_csv('../MachineLearning/DATASETS/Identificador de comentários toxicos/train.csv/train.csv')
df['is_toxic'] = df['identity_hate'] + df['insult'] + df['obscene'] + df['severe_toxic'] + df['threat'] + df['toxic']
df.drop(['identity_hate', 'insult', 'obscene', 'severe_toxic', 'threat', 'toxic', 'id'], axis=1, inplace=True)
df['is_toxic'] = df['is_toxic'].apply(lambda x: 0 if x == 0 else 1)
df.head()
# Out:
#                                         comment_text  is_toxic
# 0  Explanation\nWhy the edits made under my usern...         0
# 1  D'aww! He matches this background colour I'm s...         0
# 2  Hey man, I'm really not trying to edit war. It...         0
# 3  "\nMore\nI can't make any real suggestions on ...         0
# 4  You, sir, are my hero. Any chance you remember...         0

# %%
# Preprocessing dataset comments hate twitter
df2 = pd.read_csv('../NLP/labeled_data.csv')
df2.drop(['Unnamed: 0', 'count', 'hate_speech', 'offensive_language', 'neither'], axis=1, inplace=True)
df2['class'] = df2['class'].apply(lambda x: 0 if x == 2 else 1)
df2['comment_text'] = df2['tweet']
df2['is_toxic'] = df2['class']
df2.drop(['class', 'tweet'], axis=1, inplace=True)
df2.head()
# Out:
#                                         comment_text  is_toxic
# 0  !!! RT @mayasolovely: As a woman you shouldn't...         0
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...         1
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...         1
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...         1
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...         1

# %%
# Join datasets
df3 = pd.concat([df,df2], axis=0)
df3.head()
# Out:
#                                         comment_text  is_toxic
# 0  Explanation\nWhy the edits made under my usern...         0
# 1  D'aww! He matches this background colour I'm s...         0
# 2  Hey man, I'm really not trying to edit war. It...         0
# 3  "\nMore\nI can't make any real suggestions on ...         0
# 4  You, sir, are my hero. Any chance you remember...         0

# %%
print(f'Number of hate comments: {len(df3[df3["is_toxic"] == 1])}')
print(f'Number of non-hateful comments: {len(df3[df3["is_toxic"] == 0])}')
# Out:
# Number of hate comments: 36845
# Number of non-hateful comments: 147509

# %%
# Extracting features from text using TFiDF
X = df['comment_text']
y = df['is_toxic']

vectorizer = TfidfVectorizer(stop_words='english')
X_tfidf = vectorizer.fit_transform(X)

# %%
with open('tfidf_vectorizer.pkl', 'wb') as fin:
    joblib.dump(vectorizer, fin)

# %%
print(vectorizer.get_stop_words())
# Out:
# frozenset({'five', 'may', 'my', 'about', 'enough', 'seem', 'is', 'one', 'somehow', 'cry', 'whither', 'whom', 'moreover', 'how', 'up', 'against', 'an', 'take', 'eight', 'etc', 'had', 'latter', 'but', 'formerly', 'into', 'no', 'seemed', 'much', 'almost', 'show', 'bottom', 'sincere', 'was', 'nor', 'might', 'now', 'somewhere', 'wherever', 'nobody', 'not', 'with', 'along', 'mill', 'she', 'becoming', 'besides', 'whoever', 'through', 'whereby', 'whereafter', 'however', 'nowhere', 'hundred', 'never', 'several', 'should', 'whatever', 'seeming', 'whence', 'interest', 'amount', 'by', 'throughout', 'everything', 'if', 'this', 'bill', 'fire', 'sometimes', 'seems', 'per', 'perhaps', 'became', 'fifty', 'hasnt', 'toward', 'herself', 'thereafter', 'becomes', 'upon', 'were', 'keep', 'at', 'eleven', 'de', 'his', 'thru', 'give', 'there', 'what', 'least', 'done', 'below', 'amongst', 'latterly', 'hers', 'of', 'move', 'become', 'thereby', 'her', 'none', 'also', 'describe', 'them', 'that', 'everywhere', 'co', 'although', 'found', 'than', 'and', 'some', 'any', 'beforehand', 'cant', 'many', 'or', 'whereas', 'see', 'after', 'why', 'are', 'part', 'cannot', 'only', 'yourself', 'afterwards', 'already', 'himself', 'made', 'hereby', 'namely', 'anyone', 'as', 'do', 'mostly', 'others', 'un', 'us', 'those', 'often', 'ourselves', 'eg', 'on', 'put', 'sometime', 'thus', 'third', 'otherwise', 'next', 'indeed', 'therefore', 'three', 'whole', 'behind', 'its', 'go', 'same', 'since', 'still', 'until', 'will', 'these', 'over', 'alone', 'meanwhile', 'top', 'could', 'system', 'around', 'either', 'other', 'it', 'therein', 'within', 'i', 'who', 'between', 'across', 'call', 'their', 'where', 'yet', 'above', 'nothing', 'which', 'empty', 'couldnt', 'while', 'whenever', 'four', 'off', 'for', 'so', 'twelve', 'every', 'once', 'being', 'during', 'thereupon', 'yourselves', 'the', 'ltd', 'ie', 'under', 'amoungst', 'hereupon', 'side', 'former', 'a', 'own', 'whether', 'elsewhere', 'full', 'find', 'less', 'myself', 'him', 'noone', 'first', 'via', 'have', 'last', 'hence', 'we', 'your', 'out', 'would', 'all', 'something', 'here', 'mine', 'thence', 'further', 'forty', 'towards', 'each', 'me', 'someone', 'such', 'when', 'without', 'more', 'whose', 'back', 'been', 'beside', 'then', 'he', 'very', 'ever', 'herein', 'nine', 'name', 'be', 'down', 'together', 'whereupon', 'well', 'due', 'themselves', 'itself', 'beyond', 'though', 'they', 'neither', 'inc', 'most', 're', 'anyway', 'anything', 'before', 'anywhere', 'fill', 'ours', 'sixty', 'else', 'too', 'another', 'wherein', 'yours', 'front', 'thin', 'get', 'fifteen', 'has', 'from', 'anyhow', 'even', 'please', 'to', 'hereafter', 'serious', 'rather', 'two', 'again', 'nevertheless', 'in', 'everyone', 'onto', 'con', 'our', 'thick', 'detail', 'few', 'always', 'because', 'except', 'both', 'must', 'six', 'am', 'twenty', 'you', 'ten', 'among', 'can'})

# %%
vectorizer.vocabulary_
# Out:
# {'explanation': 62425,
#  'edits': 56947,
#  'username': 174749,
#  'hardcore': 76786,
#  'metallica': 107782,
#  'fan': 63714,
#  'reverted': 141473,
#  'weren': 180154,
#  'vandalisms': 175621,
#  'just': 91508,
#  'closure': 39000,
#  'gas': 70200,
#  'voted': 178116,
#  'new': 115856,
#  'york': 185478,
#  'dolls': 53793,
#  'fac': 63076,
#  'don': 53911,
#  'remove': 139889,
#  'template': 164243,
#  'talk': 162732,
#  'page': 123573,
#  'retired': 141226,
#  '89': 8806,
#  '205': 3503,
#  '38': 5730,
#  '27': 4536,
#  'aww': 22077,
#  'matches': 105297,
#  'background': 22670,
#  'colour': 40130,
#  'seemingly': 148463,
#  'stuck': 158915,
#  'thanks': 165094,
#  '21': 3845,
#  '51': 6819,
#  'january': 89152,
#  '11': 1040,
#  '2016': 3376,
#  'utc': 174937,
#  'hey': 78867,
#  'man': 103742,
#  'really': 137622,
#  'trying': 170113,
#  'edit': 56839,
#  'war': 178969,
#  'guy': 75330,
#  'constantly': 42205,
#  'removing': 139904,
#  'relevant': 139583,
#  'information': 85398,
#  'talking': 162781,
#  'instead': 86154,
#  'care': 33942,
#  'formatting': 67291,
#  'actual': 11502,
#  'info': 85325,
#  'make': 103297,
#  'real': 137553,
#  'suggestions': 159871,
#  'improvement': 84084,
#  'wondered': 182918,
#  'section': 148305,
#  'statistics': 157497,
#  'later': 97486,
#  'subsection': 159425,
#  'types': 171081,
#  'accidents': 10896,
#  'think': 165998,
#  'references': 138763,
#  'need': 115104,
#  'tidying': 166757,
#  'exact': 61754,
#  'format': 67282,
#  'date': 47399,
#  'does': 53649,
#  'preferences': 131530,
#  'style': 159095,
#  'want': 178931,
#  'let': 98719,
#  'know': 94834,
#  'appears': 17852,
#  'backlog': 22685,
#  'articles': 19554,
#  'review': 141494,
#  'guess': 74880,
#  'delay': 48863,
#  'reviewer': 141501,
#  'turns': 170688,
#  'listed': 100073,
#  'form': 67261,
#  'wikipedia': 181560,
#  'good_article_nominations': 73040,
#  'transport': 169054,
#  'sir': 152408,
#  'hero': 78657,
#  'chance': 35972,
#  'remember': 139792,
#  'congratulations': 41724,
#  'use': 174640,
#  'tools': 167990,
#  'cocksucker': 39519,
#  'piss': 128551,
#  'work': 183173,
#  'vandalism': 175613,
#  'matt': 105475,
#  'shirvington': 150739,
#  'article': 19484,
#  'banned': 23614,
#  'sorry': 155066,
#  'word': 183102,
#  'nonsense': 117579,
#  'offensive': 119925,
#  'intending': 86418,
#  'write': 183653,
#  'wow': 183415,
#  'jump': 91355,
#  'merely': 107472,
#  'requesting': 140560,
#  'encyclopedic': 58903,
#  'school': 147266,
#  'reference': 138751,
#  'selective': 148660,
#  'breeding': 30331,
#  'stub': 158881,
#  'points': 129611,
#  'animal': 16570,
#  'short': 151042,
#  'messy': 107736,
#  'gives': 72090,
#  'expertise': 62385,
#  'eugenics': 61141,
#  '93': 9035,
#  '161': 2082,
#  '107': 942,
#  '169': 2196,
#  'alignment': 14479,
#  'subject': 159283,
#  'contrary': 42656,
#  'dulithgow': 55467,
#  'fair': 63395,
#  'rationale': 137104,
#  'image': 83415,
#  'wonju': 182952,
#  'jpg': 91013,
#  'uploading': 174266,
#  'notice': 118079,
#  'specifies': 155772,
#  'used': 174650,
#  'constitutes': 42244,
#  'addition': 11707,
#  'boilerplate': 28836,
#  'description': 49966,
#  'specific': 155750,
#  'using': 174809,
#  'consistent': 42104,
#  'include': 84423,
#  'uploaded': 174262,
#  'media': 106546,
#  'consider': 42051,
#  'checking': 36544,
#  'specified': 155771,
#  'pages': 123627,
#  'list': 99999,
#  'edited': 56857,
#  'clicking': 38808,
#  'contributions': 42718,
#  'link': 99776,
#  'located': 100614,
#  'logged': 100729,
#  'selecting': 148657,
#  'dropdown': 54992,
#  'box': 29751,
#  'note': 118014,
#  'images': 83453,
#  '2006': 3161,
#  'lacking': 96698,
#  'deleted': 48932,
#  'week': 179848,
#  'described': 49955,
#  'criteria': 44855,
#  'speedy': 155874,
#  'deletion': 48959,
#  'questions': 135516,
#  'ask': 20077,
#  'copyright': 43218,
#  'thank': 165083,
#  'contribs': 42690,
#  'unspecified': 173893,
#  'source': 155223,
#  'noticed': 118088,
#  'file': 65418,
#  'currently': 45932,
#  'doesn': 53655,
#  'specify': 155775,
#  'created': 44513,
#  'content': 42436,
#  'status': 157527,
#  'unclear': 172238,
#  'did': 51156,
#  'create': 44511,
#  'owner': 123067,
#  'obtained': 119483,
#  'website': 179768,
#  'taken': 162632,
#  'restatement': 141003,
#  'terms': 164573,
#  'usually': 174900,
#  'sufficient': 159805,
#  'holder': 80043,
#  'different': 51323,
#  'publisher': 134125,
#  'acknowledged': 11246,
#  'adding': 11699,
#  'add': 11653,
#  'proper': 133144,
#  'licensing': 99212,
#  'tag': 162440,
#  'took': 167971,
#  'picture': 128055,
#  'audio': 21212,
#  'video': 177005,
#  'release': 139539,
#  'gfdl': 71468,
#  'believe': 25479,
#  'meets': 106764,
#  'tags': 162477,
#  'files': 65437,
#  'tagged': 162455,
#  'following': 66873,
#  'unsourced': 173885,
#  'untagged': 173964,
#  'copyrighted': 43225,
#  'non': 117424,
#  'free': 67999,
#  'license': 99206,
#  '48': 6510,
#  'hours': 80944,
#  'bbq': 24635,
#  'lets': 98750,
#  'discuss': 52302,
#  'maybe': 105762,
#  'phone': 127696,
#  'exclusive': 61957,
#  'group': 74482,
#  'wp': 183432,
#  'talibans': 162719,
#  'good': 73039,
#  'destroying': 50214,
#  'self': 148678,
#  'appointed': 17969,
#  'purist': 134509,
#  'gang': 69954,
#  'asks': 20108,
#  'abt': 10657,
#  'anti': 17100,
#  'social': 154193,
#  'destructive': 50221,
#  'contribution': 42717,
#  'sityush': 152573,
#  'clean': 38646,
#  'behavior': 25267,
#  'issue': 88187,
#  'nonsensical': 117586,
#  'warnings': 179101,
#  'start': 157346,
#  'throwing': 166463,
#  'accusations': 11082,
#  'making': 103358,
#  'ad': 11567,
#  'hominem': 80311,
#  'attacks': 20972,
#  'isn': 88066,
#  'going': 72829,
#  'strengthen': 158628,
#  'argument': 18890,
#  'look': 101027,
#  'like': 99462,
#  'abusing': 10696,
#  'power': 130912,
#  'admin': 11963,
#  'probably': 132462,
#  'single': 152272,
#  'talked': 162763,
#  'event': 61449,
#  'int': 86300,
#  'news': 115985,
#  'late': 97474,
#  'absence': 10561,
#  'notable': 117961,
#  'living': 100330,
#  'ex': 61746,
#  'president': 131841,
#  'attend': 21032,
#  'certainly': 35563,
#  'dedicating': 48340,
#  'aircracft': 13576,
#  'carrier': 34201,
#  'intend': 86413,
#  'revert': 141466,
#  'hopes': 80601,
#  'attracting': 21104,
#  'attention': 21048,
#  'willing': 182115,
#  'throw': 166452,
#  'quite': 135666,
#  'liberally': 99094,
#  'achieve': 11193,
#  'level': 98817,
#  'civility': 38296,
#  'rational': 137102,
#  'discussion': 52313,
#  'topic': 168062,
#  'resolve': 140827,
#  'matter': 105494,
#  'peacefully': 125696,
#  'oh': 120123,
#  'girl': 71997,
#  'started': 157350,
#  'arguments': 18902,
#  'nose': 117899,
#  'belong': 25593,
#  'yvesnimmo': 185937,
#  'said': 145179,
#  'situation': 152553,
#  'settled': 149499,
#  'apologized': 17733,
#  'juelz': 91242,
#  'santanas': 145957,
#  'age': 12944,
#  '2002': 3113,
#  'santana': 145956,
#  '18': 2426,
#  'years': 184978,
#  'old': 120365,
#  'came': 33172,
#  'february': 64526,
#  '18th': 2647,
#  'makes': 103336,
#  'turn': 170661,
#  '19': 2652,
#  'songs': 154840,
#  'diplomats': 51802,
#  'neff': 115160,
#  'signed': 151776,
#  'cam': 33133,
#  'label': 96592,
#  'roc': 142838,
#  'fella': 64708,
#  '2003': 3122,
#  '20': 3085,
#  'coming': 40362,
#  'singles': 152279,
#  'town': 168468,
#  'yes': 185146,
#  'born': 29390,
#  '1983': 2859,
#  'older': 120382,
#  'lloyd': 100455,
#  'banks': 23595,
#  '22': 3946,
#  'birthday': 27372,
#  'passed': 125035,
#  'homie': 80305,
#  '23': 4116,
#  'death': 47904,
#  'god': 72664,
#  'forbid': 67052,
#  'thinking': 166014,
#  'equals': 60034,
#  'caculator': 32746,
#  'stop': 158256,
#  'changing': 36044,
#  'year': 184958,
#  'birth': 27365,
#  'bye': 32410,
#  'come': 40267,
#  'comming': 40526,
#  'tosser': 168289,
#  'redirect': 138473,
#  'voydan': 178172,
#  'pop': 130229,
#  'georgiev': 71169,
#  'chernodrinski': 36762,
#  'mitsurugi': 109929,
#  'point': 129591,
#  'sense': 148967,
#  'argue': 18876,
#  'hindi': 79333,
#  'ryo': 144579,
#  'sakazaki': 145254,
#  'mean': 106343,
#  'bother': 29544,
#  'writing': 183677,
#  'regarding': 139009,
#  'posted': 130640,
#  'acctually': 11034,
#  'better': 26272,
#  'closer': 38982,
#  'premature': 131632,
#  'wrestling': 183617,
#  'deaths': 47934,
#  'catagory': 34540,
#  'men': 107179,
#  'surely': 160741,
#  'delting': 49128,
#  'recent': 137965,
#  'read': 137481,
#  'filmplot': 65521,
#  'editing': 56875,
#  'film': 65498,
#  'simply': 152144,
#  'entirely': 59586,
#  'unnecessary': 173473,
#  'details': 50265,
#  'bad': 22767,
#  'damage': 46864,
#  '45': 6353,
#  'yeah': 184944,
#  'studying': 158966,
#  'deepu': 48421,
#  'snowflakes': 154043,
#  'symmetrical': 161541,
#  'geometry': 71107,
#  'stated': 157405,
#  'snowflake': 154042,
#  'symmetric': 161539,
#  'arms': 19180,
#  'assertion': 20301,
#  'true': 169967,
#  'according': 10961,
#  'kenneth': 93261,
#  'libbrecht': 99061,
#  'unattractive': 172045,
#  'irregular': 87708,
#  'crystals': 45366,
#  'far': 63872,
#  'common': 40593,
#  'variety': 175903,
#  'http': 81245,
#  'www': 183977,
#  'caltech': 33099,
#  'edu': 57029,
#  'atomic': 20878,
#  'snowcrystals': 154030,
#  'myths': 113438,
#  'htm': 81229,
#  'perfection': 126455,
#  'site': 152503,
#  'facts': 63208,
#  'decent': 48122,
#  'number': 118676,
#  'falsities': 63612,
#  'forgive': 67227,
#  'im': 83404,
#  'dont': 54025,
#  'signpost': 151821,
#  '24': 4200,
#  'september': 149140,
#  '2012': 3313,
#  'unsubscribe': 173916,
#  'considering': 42066,
#  '1st': 3053,
#  'paragraph': 124390,
#  'understand': 172548,
#  'reasons': 137744,
#  'sure': 160735,
#  'data': 47373,
#  'necessarily': 115036,
#  'wrong': 183718,
#  'persuaded': 126926,
#  'strategy': 158503,
#  'introducing': 87060,
#  'academic': 10743,
#  'honors': 80482,
#  'unhelpful': 173003,
#  'approach': 18070,
#  'sitting': 152543,
#  'justices': 91534,
#  'similarly': 152050,
#  'enhanced': 59284,
#  'changes': 36034,
#  'support': 160597,
#  'view': 177083,
#  'invite': 87257,
#  'visit': 177553,
#  'written': 183695,
#  'pairs': 123725,
#  'jurists': 91478,
#  'a1': 9777,
#  'benjamin': 25797,
#  'cardozo': 33937,
#  'a2': 9803,
#  'learned': 98011,
#  'hand': 76416,
#  'b1': 22391,
#  'john': 90555,
#  'marshall': 104832,
#  'harlan': 76891,
#  'b2': 22406,
#  'ii': 83095,
#  'question': 135493,
#  'current': 45924,
#  'version': 176677,
#  'pair': 123720,
#  'improved': 84082,
#  'credentials': 44568,
#  'introductory': 87068,
#  'helps': 78290,
#  'repeat': 140143,
#  'wry': 183758,
#  'kathleen': 92735,
#  'sullivan': 159997,
#  'stanford': 157192,
#  'law': 97705,
#  'suggests': 159878,
#  'harvard': 77109,
#  'faculty': 63229,
#  'wonder': 182916,
#  'antonin': 17300,
#  'scalia': 146860,
#  'avoided': 21924,
#  'learning': 98017,
#  'managed': 103759,
#  'grasp': 73860,
#  'processes': 132573,
#  'judging': 91208,
#  'hope': 80586,
#  'anecdote': 16354,
#  'gently': 70991,
#  'illustrates': 83346,
#  'humorous': 81561,
#  'stronger': 158783,
#  'clarence': 38481,
#  'thomas': 166173,
#  'mentions': 107356,
#  'wanting': 178941,
#  'return': 141324,
#  'degree': 48742,
#  'yale': 184652,
#  'minimum': 109122,
#  'questioning': 135506,
#  'deserves': 50019,
#  'reconsidered': 138214,
#  'radial': 136068,
#  'symmetry': 161544,
#  'extinct': 62681,
#  'lineages': 99683,
#  'included': 84424,
#  'echinodermata': 56595,
#  'bilateral': 26958,
#  'homostelea': 80389,
#  'asymmetrical': 20657,
#  'cothurnocystis': 43752,
#  'stylophora': 159131,
#  'apologize': 17732,
#  'reconciling': 138181,
#  'knowledge': 94863,
#  'sources': 155243,
#  've': 176111,
#  'history': 79573,
#  'studies': 158945,
#  'archaeology': 18540,
#  'scan': 146889,
#  'mail': 103085,
#  'translate': 168966,
#  'mother': 111616,
#  'child': 36971,
#  'case': 34333,
#  'michael': 108211,
#  'jackson': 88742,
#  'studied': 158942,
#  'motives': 111685,
#  'reasonings': 137738,
#  'judged': 91196,
#  'character': 36162,
#  'harshly': 77060,
#  'wacko': 178493,
#  'jacko': 88728,
#  'tell': 164144,
#  'ignore': 83024,
#  'incriminate': 84613,
#  'continue': 42551,
#  'refuting': 138990,
#  'bullshit': 31713,
#  'jayjg': 89387,
#  'keeps': 93059,
#  '01': 158,
#  '16': 2051,
#  'jun': 91370,
#  '2005': 3143,
#  'ok': 120261,
#  'bit': 27459,
#  'example': 61808,
#  'base': 24133,
#  'duck': 55326,
#  'barnstar': 23952,
#  'life': 99311,
#  'stars': 157328,
#  'post': 130613,
#  'block': 28119,
#  'expires': 62402,
#  'funny': 69072,
#  'thing': 165975,
#  'uncivil': 172218,
#  'heading': 77701,
#  'fight': 65337,
#  'freedom': 68028,
#  'contain': 42371,
#  'praise': 131156,
#  'looked': 101032,
#  'months': 111022,
#  'ago': 13127,
#  'able': 10373,
#  'quickly': 135559,
#  'text': 164874,
#  'hard': 76772,
#  'drive': 54905,
#  'meaning': 106364,
#  'updating': 174212,
#  'sound': 155187,
#  'time': 166930,
#  'generating': 70827,
#  'spent': 155939,
#  'drum': 55065,
#  'freely': 68062,
#  'licensed': 99207,
#  'length': 98515,
#  'classical': 38551,
#  'music': 112889,
#  'unfortunately': 172920,
#  'attempts': 21025,
#  'failed': 63366,
#  'effectively': 57183,
#  'wikiproject': 181707,
#  'interested': 86563,
#  'wikipedia_talk': 181589,
#  'wikiproject_classical_music': 181717,
#  'archive_5': 18659,
#  'need_help': 115105,
#  '21wikipedia_talk': 3945,
#  'wikiproject_music': 181741,
#  'archive_3': 18654,
#  'i_could_use_some_helpwikipedia_talk': 82269,
#  'archive_2': 18651,
#  'raulbot': 137178,
#  '2c_and_the_music_list': 4952,
#  'given': 72083,
#  'featured': 64501,
#  'digg': 51417,
#  'com': 40191,
#  'wikipedia_has_free_classical_music_downloads': 181569,
#  'got': 73336,
#  '1600': 2053,
#  'diggs': 51428,
#  'imo': 83748,
#  'impressive': 84045,
#  'process': 132569,
#  'things': 165992,
#  'subpages': 159384,
#  'rfa': 141698,
#  'noseptember': 117907,
#  '2004': 3133,
#  'differences': 51317,
#  'el_c': 57624,
#  'surprised': 160824,
#  'left': 98197,
#  'straw': 158545,
#  'claimed': 38397,
#  'donohue': 54015,
#  'position': 130526,
#  'practitioners': 131114,
#  'researchers': 140674,
#  'field': 65277,
#  'ignored': 83026,
#  'dsm': 55180,
#  'exactly': 61765,
#  'quote': 135726,
#  'says': 146625,
#  'agrees': 13173,
#  'combating': 40227,
#  'notion': 118116,
#  'absurd': 10649,
#  'claim': 38393,
#  'pedophilia': 125883,
#  'sexual': 149634,
#  'orientation': 121723,
#  'hold': 80038,
#  'unfair': 172841,
#  'disorder': 52580,
#  'divided': 53177,
#  'end': 58962,
#  'day': 47593,
#  'value': 175512,
#  'judgment': 91209,
#  'cantor': 33569,
#  'pointed': 129595,
#  'earlier': 56273,
#  'thread': 166337,
#  'scientific': 147451,
#  'judgement': 91197,
#  'choose': 37374,
#  'clearly': 38699,
#  'pretend': 131951,
#  'basis': 24216,
#  'mainland': 103136,
#  'asia': 20030,
#  'includes': 84428,
#  'lower': 101424,
#  'basin': 24210,
#  'china': 37060,
#  'yangtze': 184725,
#  'river': 142490,
#  'korea': 95333,
#  'fine': 65631,
#  'citation': 38152,
#  'comprehensive': 41036,
#  'dna': 53406,
#  'study': 158963,
#  'hammer': 76335,
#  'generarizations': 70821,
#  'speculation': 155823,
#  'yayoi': 184884,
#  'culture': 45694,
#  'brought': 30978,
#  'japan': 89165,
#  'migrants': 108571,
#  'trace': 168583,
#  'roots': 143374,
#  'southeast': 155306,
#  'south': 155291,
#  'describes': 49956,
#  'migration': 108575,
#  'based': 24141,
#  'sry': 156810,
#  '465': 6450,
#  'genes': 70851,
#  'close': 38975,
#  'lineage': 99682,
#  'haplogroups': 76647,
#  'm122': 102247,
#  'm95': 102312,
#  'reiterates': 139396,
#  'entire': 59583,
#  'haplogroup': 76645,
#  'proposed': 133224,
#  'asian': 20032,
#  'origin': 121746,
#  'definition': 48628,
#  'southern': 155311,
#  'hypothesizes': 82140,
#  'dispersals': 52639,
#  'neolithic': 115409,
#  'farmers': 63957,
#  'eventually': 61469,
#  'concluding': 41314,
#  'states': 157441,
#  'propose': 133223,
#  'chromosomes': 37630,
#  'descend': 49911,
#  'prehistoric': 131578,
#  'origins': 121785,
#  'southeastern': 155307,
#  'agriculture': 13201,
#  'region': 139083,
#  'global': 72340,
#  'sample': 145639,
#  'consisted': 42095,
#  '500': 6727,
#  'males': 103506,
#  '39': 5789,
#  'populations': 130318,
#  'including': 84431,
#  'sampled': 145640,
#  'japanese': 89170,
#  'archipelago': 18602,
#  'pretty': 131993,
#  'warren': 179134,
#  'county': 43988,
#  'surrounding': 160858,
#  'regions': 139100,
#  'glens': 72283,
#  'falls': 63574,
#  'hospital': 80805,
#  'qualifies': 135246,
#  'native': 114510,
#  'rachel': 135974,
#  'ray': 137255,
#  'actually': 11509,
#  'lake': 96901,
#  'luzerne': 102000,
#  'preceding': 131330,
#  'unsigned': 173861,
#  'comment': 40457,
#  'added': 11672,
#  '70': 7987,
#  '100': 723,
#  '229': 4038,
#  '154': 1929,
#  '04': 347,
#  '28': 4676,
#  '57': 7142,
#  'august': 21278,
#  '2007': 3188,
#  'hi': 78955,
#  'explicit': 62450,
#  'fenian': 64806,
#  'warring': 179147,
#  'giant': 71693,
#  'causeway': 34851,
#  'terrorism': 164660,
#  'notability': 117952,
#  'rurika': 144337,
#  'kasuga': 92685,
#  'placed': 128739,
#  'speedily': 155858,
#  'person': 126849,
#  'people': 126300,
#  'band': 23444,
#  'club': 39073,
#  'company': 40740,
#  'web': 179676,
#  'indicate': 84828,
#  'assert': 20294,
#  'guidelines': 74942,
#  'generally': 70813,
#  'accepted': 10841,
#  'contest': 42472,
#  'tagging': 162460,
#  'existing': 62181,
#  'db': 47654,
#  'leave': 98054,
#  'explaining': 62418,
#  'hesitate': 78759,
#  'confirm': 41581,
#  'check': 36530,
#  'biographies': 27190,
#  'sites': 152518,
#  'bands': 23487,
#  'companies': 40734,
#  'feel': 64605,
#  'lead': 97926,
#  'briefly': 30543,
#  'summarize': 160076,
#  'armenia': 19126,
#  'necessary': 115041,
#  'thinks': 166021,
#  'sentence': 149022,
#  'redundant': 138603,
#  'welcome': 180014,
#  'tfd': 164963,
#  'eced': 56575,
#  'responded': 140937,
#  'seeing': 148446,
#  'responses': 140963,
#  'response': 140961,
#  'saw': 146551,
#  'chicago': 36887,
#  'gay': 70378,
#  'antisemmitian': 17241,
#  'archangel': 18549,
#  'white': 180722,
#  'tiger': 166803,
#  'meow': 107388,
#  'greetingshhh': 74134,
#  'uh': 171567,
#  'ways': 179475,
#  'erased': 60141,
#  'ww2': 183941,
#  'holocaust': 80149,
#  'brutally': 31143,
#  'slaying': 153157,
#  'jews': 90012,
#  'gays': 70419,
#  'gypsys': 75481,
#  'slavs': 153150,
#  'semitian': 148849,
#  'shave': 150198,
#  'head': 77669,
#  'bald': 23187,
#  'skinhead': 152837,
#  'meetings': 106763,
#  'doubt': 54314,
#  'words': 183136,
#  'bible': 26689,
#  'homosexuality': 80377,
#  'deadly': 47827,
#  'sin': 152183,
#  'pentagram': 126248,
#  'tatoo': 163367,
#  'forehead': 67128,
#  'satanistic': 146293,
#  'masses': 105175,
#  'pals': 123980,
#  'warning': 179096,
#  'fucking': 68734,
#  'won': 182912,
#  'appreciate': 18030,
#  'nazi': 114755,
#  'shwain': 151447,
#  'wish': 182449,
#  'anymore': 17417,
#  'beware': 26342,
#  'dark': 47198,
#  'fuck': 68695,
#  'filthy': 65549,
#  'ass': 20214,
#  'dry': 55115,
#  'screwed': 147782,
#  'someones': 154713,
#  'having': 77417,
#  'templates': 164252,
#  'dominance': 53856,
#  'bow': 29710,
#  'almighty': 14872,
#  'administrators': 12023,
#  'play': 128986,
#  'outside': 122593,
#  'mom': 110634,
#  '76': 8242,
#  '122': 1319,
#  '79': 8364,
#  '82': 8574,
#  'lisak': 99967,
#  'criticism': 44883,
#  'present': 131799,
#  'conforms': 41642,
#  'npv': 118395,
#  'rule': 144168,
#  'neutral': 115772,
#  'begin': 25216,
#  'offer': 119932,
#  'polygraph': 129993,
#  'concerned': 41259,
#  'results': 141099,
#  'shocks': 150920,
#  'complainant': 40883,
#  'lies': 99296,
#  'uncovered': 172356,
#  'recantation': 137912,
#  'perfectly': 126460,
#  'valid': 175445,
#  'telling': 164152,
#  'truth': 170063,
#  'machine': 102475,
#  'investigator': 87212,
#  'kanin': 92281,
#  'research': 140666,
#  'followup': 66877,
#  'recanted': 137914,
#  'story': 158336,
#  'possible': 130592,
#  'verify': 176577,
#  'false': 63583,
#  'recantations': 137913,
#  'followups': 66878,
#  'events': 61462,
#  'matched': 105296,
#  'accused': 11090,
#  'happened': 76661,
#  'arguing': 18888,
#  'respected': 140896,
#  'phd': 127462,
#  'baseless': 24150,
#  'agree': 13160,
#  'wasn': 179234,
#  'ammended': 15674,
#  'appropriate': 18092,
#  'significance': 151797,
#  'lazy': 97833,
#  'change': 36020,
#  'goes': 72777,
#  'claims': 38407,
#  'stalking': 157088,
#  'absolute': 10590,
#  'rubbish': 143998,
#  'serves': 149397,
#  'aggravate': 13020,
#  'assumed': 20463,
#  'faith': 63458,
#  'intentions': 86458,
#  'suggested': 159861,
#  'seen': 148467,
#  'reason': 137723,
#  'suggest': 159859,
#  'ulterior': 171760,
#  'motive': 111683,
#  'mass': 105130,
#  'links': 99817,
#  'suggestion': 159868,
#  'administrative': 12012,
#  'mentioned': 107346,
#  'role': 143083,
#  'party': 124930,
#  'disagreement': 51954,
#  'rate': 137056,
#  'conflict': 41610,
#  'extend': 62630,
#  'spurious': 156537,
#  'unfounded': 172936,
#  ...}

# %%
print(vectorizer.idf_)
# Out:
# [  6.49561527   5.89434905  10.78302593 ...,  12.28710333  12.28710333
#   12.28710333]

# %%
text_clf =  MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
cv = ShuffleSplit(n_splits=10, test_size=0.3, random_state=1)
scores = cross_val_score(text_clf, X_tfidf, y, cv=cv, scoring='f1_macro')
print(f'F1 Score: {scores.mean()} (+/- {scores.std() * 2})')
# Out:
# F1 Score: 0.8698825479448024 (+/- 0.009330115733128645)

# %%
joblib.dump(text_clf, 'model_mlp_cls.pkl')
# Out:
# ['model_mlp_cls.pkl']

# %%
# !pip install googletrans
# Out:
# Collecting googletrans
#   Downloading https://files.pythonhosted.org/packages/89/70/8df7605661051e678e097bbbb6e226583fa0f5742ad1d46aaf1be85217d2/googletrans-2.2.0.tar.gz
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from googletrans)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->googletrans)
# Requirement already satisfied: idna<2.7,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->googletrans)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->googletrans)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->googletrans)
# Building wheels for collected packages: googletrans
#   Running setup.py bdist_wheel for googletrans ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/03/67/83/38f65b30bb5ca9296e5045c50a3f4876eec8df0c47adaca385
# Successfully built googletrans
# Installing collected packages: googletrans
# Successfully installed googletrans-2.2.0
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from googletrans import Translator
translator = Translator()
translator.translate('Olá mundo')
# <Translated src=ko dest=en text=Good evening. pronunciation=Good evening.>
trans = translator.translate('Olá mundo', dest='en')
trans.text
# Out:
# 'Hello World'

# %%
detect = translator.detect('이 문장은 한글로 쓰여졌습니다.')
detect.lang
# Out:
# 'ko'
